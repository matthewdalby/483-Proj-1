# %%
import numpy as np
import pandas as pd

survey_data = pd.read_csv(r"C:\Users\Tuse\Desktop\HappinessData-1.csv")

#Move Target column to end

column_to_move = survey_data.pop("Unhappy/Happy")
survey_data.insert(len(survey_data.columns)-1, "Unhappy/Happy", column_to_move)

print(survey_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\ops\array_ops.py:142, in _na_arithmetic_op(left, right, op, is_cmp)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=140'>141</a> try:
# --> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=141'>142</a>     result = expressions.evaluate(op, left, right)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=142'>143</a> except TypeError:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:235, in evaluate(op, a, b, use_numexpr)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/computation/expressions.py?line=232'>233</a>     if use_numexpr:
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/computation/expressions.py?line=233'>234</a>         # error: "None" not callable
# --> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/computation/expressions.py?line=234'>235</a>         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/computation/expressions.py?line=235'>236</a> return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/computation/expressions.py?line=67'>68</a> with np.errstate(all="ignore"):
# ---> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/computation/expressions.py?line=68'>69</a>     return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Tuse\Desktop\483 Proj 1\proj1.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Tuse/Desktop/483%20Proj%201/proj1.ipynb#ch0000000?line=5'>6</a> #Move Target column to end
#       <a href='vscode-notebook-cell:/c%3A/Users/Tuse/Desktop/483%20Proj%201/proj1.ipynb#ch0000000?line=7'>8</a> column_to_move = survey_data.pop("Unhappy/Happy")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tuse/Desktop/483%20Proj%201/proj1.ipynb#ch0000000?line=8'>9</a> survey_data.insert(len(survey_data.columns-1), "Unhappy/Happy", column_to_move)
#      <a href='vscode-notebook-cell:/c%3A/Users/Tuse/Desktop/483%20Proj%201/proj1.ipynb#ch0000000?line=10'>11</a> print(survey_data)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\ops\common.py:65, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/common.py?line=60'>61</a>             return NotImplemented
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/common.py?line=62'>63</a> other = item_from_zerodim(other)
# ---> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/common.py?line=64'>65</a> return method(self, other)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\arraylike.py:97, in OpsMixin.__sub__(self, other)
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/arraylike.py?line=94'>95</a> @unpack_zerodim_and_defer("__sub__")
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/arraylike.py?line=95'>96</a> def __sub__(self, other):
# ---> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/arraylike.py?line=96'>97</a>     return self._arith_method(other, operator.sub)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:5649, in Index._arith_method(self, other, op)
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/indexes/base.py?line=5642'>5643</a> """
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/indexes/base.py?line=5643'>5644</a> Wrapper used to dispatch arithmetic operations.
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/indexes/base.py?line=5644'>5645</a> """
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/indexes/base.py?line=5646'>5647</a> from pandas import Series
# -> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/indexes/base.py?line=5648'>5649</a> result = op(Series(self), other)
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/indexes/base.py?line=5649'>5650</a> if isinstance(result, tuple):
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/indexes/base.py?line=5650'>5651</a>     return (Index(result[0]), Index(result[1]))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\ops\common.py:65, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/common.py?line=60'>61</a>             return NotImplemented
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/common.py?line=62'>63</a> other = item_from_zerodim(other)
# ---> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/common.py?line=64'>65</a> return method(self, other)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\arraylike.py:97, in OpsMixin.__sub__(self, other)
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/arraylike.py?line=94'>95</a> @unpack_zerodim_and_defer("__sub__")
#      <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/arraylike.py?line=95'>96</a> def __sub__(self, other):
# ---> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/arraylike.py?line=96'>97</a>     return self._arith_method(other, operator.sub)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:4998, in Series._arith_method(self, other, op)
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/series.py?line=4995'>4996</a> lvalues = extract_array(self, extract_numpy=True)
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/series.py?line=4996'>4997</a> rvalues = extract_array(other, extract_numpy=True)
# -> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/series.py?line=4997'>4998</a> result = ops.arithmetic_op(lvalues, rvalues, op)
#    <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/series.py?line=4999'>5000</a> return self._construct_result(result, name=res_name)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\ops\array_ops.py:189, in arithmetic_op(left, right, op)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=186'>187</a> else:
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=187'>188</a>     with np.errstate(all="ignore"):
# --> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=188'>189</a>         res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=190'>191</a> return res_values
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\ops\array_ops.py:149, in _na_arithmetic_op(left, right, op, is_cmp)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=143'>144</a>     if is_cmp:
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=144'>145</a>         # numexpr failed on comparison op, e.g. ndarray[float] > datetime
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=145'>146</a>         #  In this case we do not fall back to the masked op, as that
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=146'>147</a>         #  will handle complex numbers incorrectly, see GH#32047
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=147'>148</a>         raise
# --> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=148'>149</a>     result = _masked_arith_op(left, right, op)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=150'>151</a> if is_cmp and (is_scalar(result) or result is NotImplemented):
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=151'>152</a>     # numpy returned a scalar instead of operating element-wise
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=152'>153</a>     # e.g. numeric array vs str
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=153'>154</a>     return invalid_comparison(left, right, op)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\ops\array_ops.py:111, in _masked_arith_op(x, y, op)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=108'>109</a>     if mask.any():
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=109'>110</a>         with np.errstate(all="ignore"):
# --> <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=110'>111</a>             result[mask] = op(xrav[mask], y)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=112'>113</a> result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#     <a href='file:///~/AppData/Roaming/Python/Python39/site-packages/pandas/core/ops/array_ops.py?line=113'>114</a> result = result.reshape(x.shape)  # 2D compat
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
